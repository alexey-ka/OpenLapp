# %%
import numpy as np
import config
from yatcxparser import TcxParser
from utils import time_to_seconds
import os
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# get random file with powers
filename = str(Path(os.getcwd())/Path('data/Sport5/1')/'9.tcx')
lappparser = TcxParser(filename, pre_read=True)

# %%
fig = plt.figure(figsize=(20,10))
ax = plt.axes()
y = lappparser.powers
x = np.arange(len(y))
ax.plot(x,y,color='#ED2840')
# np.arange(len(np.array(y)))
